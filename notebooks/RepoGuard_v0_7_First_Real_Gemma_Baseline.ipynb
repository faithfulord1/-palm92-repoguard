# %% [markdown]
# # Palm92 RepoGuard v0.7: First Real Gemma Baseline
#
# Use a GPU runtime. This notebook installs RepoGuard, checks the GPU, and runs `baseline-v001` on the controlled task pack.

# %%
# !git clone https://github.com/faithfulord1/palm92-repoguard.git
# %cd palm92-repoguard
# !python -m pip install -U pip
# !python -m pip install -e '.[gemma,dev]'

# %%
# !python scripts/v0_7_preflight.py

# %%
# !python scripts/run_v0_7_baseline.py

# %%
from pathlib import Path
print(Path('artifacts/v0.7/baseline-v001-summary.json').read_text())

# %% [markdown]
# ## Preserve the evidence
# Keep the generated JSONL and summary files unchanged. They are raw experimental evidence for the competition writeup.
